# %%
from keras.preprocessing.image import load_img, save_img, img_to_array
import numpy as np
from scipy.optimize import fmin_l_bfgs_b
import time
import argparse

from keras.applications import vgg19
from keras import backend as K

# %%
K.clear_session()

# %%
K.image_data_format()
# Out:
# 'channels_last'

# %%
base_image_path = '/content/drive/My Drive/Colab Notebooks/Neural Style Transfer/Photos/teo.jpg'
style_reference_image_path = '/content/drive/My Drive/Colab Notebooks/Neural Style Transfer/Photos/toollateralus.jpg'
result_prefix = '/content/drive/My Drive/Colab Notebooks/Neural Style Transfer/TeoTries/teo_toollateralus'

# %%
iterations = 800

# %%
# these are the weights of the different loss components
total_variation_weight = 1.0
style_weight = 1.0
content_weight = 0.025

# %%
# dimensions of the generated picture.
width, height = load_img(base_image_path).size
img_nrows = 400
img_ncols = int(width * img_nrows / height) # keep the width/height proportion

# %%
# util function to open, resize and format pictures into appropriate tensors

def preprocess_image(image_path):
    img = load_img(image_path, target_size=(img_nrows, img_ncols))
    img = img_to_array(img)
    img = np.expand_dims(img, axis=0)
    img = vgg19.preprocess_input(img)
    return img

# %%
# util function to convert a tensor into a valid image

def deprocess_image(x):
    x = x.reshape((img_nrows, img_ncols, 3))
    # Remove zero-center by mean pixel
    x[:, :, 0] += 103.939
    x[:, :, 1] += 116.779
    x[:, :, 2] += 123.68
    # 'BGR'->'RGB'
    x = x[:, :, ::-1]
    x = np.clip(x, 0, 255).astype('uint8')
    return x

# %%
# get tensor representations of our images
base_image = K.variable(preprocess_image(base_image_path))
style_reference_image = K.variable(preprocess_image(style_reference_image_path))

# this will contain our generated image
combination_image = K.placeholder((1, img_nrows, img_ncols, 3))

# combine the 3 images into a single Keras tensor
input_tensor = K.concatenate([base_image,
                              style_reference_image,
                              combination_image], axis=0)

# %%
# build the VGG19 network with our 3 images as input
# the model will be loaded with pre-trained ImageNet weights
model = vgg19.VGG19(input_tensor=input_tensor,
                    weights='imagenet', include_top=False)
print('Model loaded.')

# get the symbolic outputs of each "key" layer
outputs_dict = dict([(layer.name, layer.output) for layer in model.layers])
# Out:
# Model loaded.

# %%
print(outputs_dict)
# Out:
# {'input_1': <tf.Tensor 'concat:0' shape=(3, 400, 224, 3) dtype=float32>, 'block1_conv1': <tf.Tensor 'block1_conv1/Relu:0' shape=(3, 400, 224, 64) dtype=float32>, 'block1_conv2': <tf.Tensor 'block1_conv2/Relu:0' shape=(3, 400, 224, 64) dtype=float32>, 'block1_pool': <tf.Tensor 'block1_pool/MaxPool:0' shape=(3, 200, 112, 64) dtype=float32>, 'block2_conv1': <tf.Tensor 'block2_conv1/Relu:0' shape=(3, 200, 112, 128) dtype=float32>, 'block2_conv2': <tf.Tensor 'block2_conv2/Relu:0' shape=(3, 200, 112, 128) dtype=float32>, 'block2_pool': <tf.Tensor 'block2_pool/MaxPool:0' shape=(3, 100, 56, 128) dtype=float32>, 'block3_conv1': <tf.Tensor 'block3_conv1/Relu:0' shape=(3, 100, 56, 256) dtype=float32>, 'block3_conv2': <tf.Tensor 'block3_conv2/Relu:0' shape=(3, 100, 56, 256) dtype=float32>, 'block3_conv3': <tf.Tensor 'block3_conv3/Relu:0' shape=(3, 100, 56, 256) dtype=float32>, 'block3_conv4': <tf.Tensor 'block3_conv4/Relu:0' shape=(3, 100, 56, 256) dtype=float32>, 'block3_pool': <tf.Tensor 'block3_pool/MaxPool:0' shape=(3, 50, 28, 256) dtype=float32>, 'block4_conv1': <tf.Tensor 'block4_conv1/Relu:0' shape=(3, 50, 28, 512) dtype=float32>, 'block4_conv2': <tf.Tensor 'block4_conv2/Relu:0' shape=(3, 50, 28, 512) dtype=float32>, 'block4_conv3': <tf.Tensor 'block4_conv3/Relu:0' shape=(3, 50, 28, 512) dtype=float32>, 'block4_conv4': <tf.Tensor 'block4_conv4/Relu:0' shape=(3, 50, 28, 512) dtype=float32>, 'block4_pool': <tf.Tensor 'block4_pool/MaxPool:0' shape=(3, 25, 14, 512) dtype=float32>, 'block5_conv1': <tf.Tensor 'block5_conv1/Relu:0' shape=(3, 25, 14, 512) dtype=float32>, 'block5_conv2': <tf.Tensor 'block5_conv2/Relu:0' shape=(3, 25, 14, 512) dtype=float32>, 'block5_conv3': <tf.Tensor 'block5_conv3/Relu:0' shape=(3, 25, 14, 512) dtype=float32>, 'block5_conv4': <tf.Tensor 'block5_conv4/Relu:0' shape=(3, 25, 14, 512) dtype=float32>, 'block5_pool': <tf.Tensor 'block5_pool/MaxPool:0' shape=(3, 12, 7, 512) dtype=float32>}

# %%
# the gram matrix of an image tensor (feature-wise outer product)


def gram_matrix(x):
    assert K.ndim(x) == 3
    features = K.batch_flatten(K.permute_dimensions(x, (2, 0, 1)))
    gram = K.dot(features, K.transpose(features))
    return gram

# %%
# the "style loss" is designed to maintain
# the style of the reference image in the generated image.
# It is based on the gram matrices (which capture style) of
# feature maps from the style reference image
# and from the generated image

def style_loss(style, combination):
    assert K.ndim(style) == 3
    assert K.ndim(combination) == 3
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = img_nrows * img_ncols
    return K.sum(K.square(S - C)) / (4.0 * (channels ** 2) * (size ** 2))

# %%
# an auxiliary loss function
# designed to maintain the "content" of the
# base image in the generated image

def content_loss(base, combination):
    return K.sum(K.square(combination - base))

# %%
# the 3rd loss function, total variation loss,
# designed to keep the generated image locally coherent

def total_variation_loss(x):
    assert K.ndim(x) == 4
    a = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, 1:, :img_ncols - 1, :])
    b = K.square(
        x[:, :img_nrows - 1, :img_ncols - 1, :] - x[:, :img_nrows - 1, 1:, :])
    return K.sum(K.pow(a + b, 1.25))

# %%
# combine these loss functions into a single scalar
loss = K.variable(0.0)
layer_features = outputs_dict['block5_conv2']
base_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]
loss = loss + content_weight * content_loss(base_image_features,
                                            combination_features)

feature_layers = ['block1_conv1', 'block2_conv1',
                  'block3_conv1', 'block4_conv1',
                  'block5_conv1']
for layer_name in feature_layers:
    layer_features = outputs_dict[layer_name]
    style_reference_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_reference_features, combination_features)
    loss = loss + (style_weight / len(feature_layers)) * sl
loss = loss + total_variation_weight * total_variation_loss(combination_image)

# %%
# get the gradients of the generated image wrt the loss
grads = K.gradients(loss, combination_image)

outputs = [loss]
if isinstance(grads, (list, tuple)):
    outputs += grads
else:
    outputs.append(grads)

f_outputs = K.function([combination_image], outputs)

# %%
def eval_loss_and_grads(x):
    x = x.reshape((1, img_nrows, img_ncols, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    if len(outs[1:]) == 1:
        grad_values = outs[1].flatten().astype('float64')
    else:
        grad_values = np.array(outs[1:]).flatten().astype('float64')
    return loss_value, grad_values

# %%
# this Evaluator class makes it possible
# to compute loss and gradients in one pass
# while retrieving them via two separate functions,
# "loss" and "grads". This is done because scipy.optimize
# requires separate functions for loss and gradients,
# but computing them separately would be inefficient.

class Evaluator(object):

    def __init__(self):
        self.loss_value = None
        self.grads_values = None

    def loss(self, x):
        assert self.loss_value is None
        loss_value, grad_values = eval_loss_and_grads(x)
        self.loss_value = loss_value
        self.grad_values = grad_values
        return self.loss_value

    def grads(self, x):
        assert self.loss_value is not None
        grad_values = np.copy(self.grad_values)
        self.loss_value = None
        self.grad_values = None
        return grad_values

# %%
evaluator = Evaluator()

# %%
# run scipy-based optimization (L-BFGS) over the pixels of the generated image
# so as to minimize the neural style loss
x = preprocess_image(base_image_path)

start_time = time.time()

for i in range(iterations):
    print('Start of iteration', i)
    # start_time = time.time()
    x, min_val, info = fmin_l_bfgs_b(evaluator.loss, x.flatten(),
                                     fprime=evaluator.grads, maxfun=20)
    print('Current loss value:', min_val)
    if i % 100 == 0 or i == iterations - 1:
        # save current generated image
        img = deprocess_image(x.copy())
        fname = result_prefix + '_at_iteration_%d.png' % i
        save_img(fname, img)
        end_time = time.time()
        print('Image saved as', fname)
        print('Iteration %d completed in %ds' % (i, end_time - start_time))
# Out:
# Start of iteration 0
# Current loss value: 14997268000.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Neural Style Transfer/TeoTries/teo_toollateralus_at_iteration_0.png
# Iteration 0 completed in 2s
# Start of iteration 1
# Current loss value: 8195217400.0
# Start of iteration 2
# Current loss value: 5810899000.0
# Start of iteration 3
# Current loss value: 4886482000.0
# Start of iteration 4
# Current loss value: 4312045600.0
# Start of iteration 5
# Current loss value: 3961531600.0
# Start of iteration 6
# Current loss value: 3732219000.0
# Start of iteration 7
# Current loss value: 3563116500.0
# Start of iteration 8
# Current loss value: 3446781000.0
# Start of iteration 9
# Current loss value: 3333837800.0
# Start of iteration 10
# Current loss value: 3245693000.0
# Start of iteration 11
# Current loss value: 3173222100.0
# Start of iteration 12
# Current loss value: 3111620900.0
# Start of iteration 13
# Current loss value: 3041937700.0
# Start of iteration 14
# Current loss value: 2993989400.0
# Start of iteration 15
# Current loss value: 2945317600.0
# Start of iteration 16
# Current loss value: 2901462000.0
# Start of iteration 17
# Current loss value: 2864836900.0
# Start of iteration 18
# Current loss value: 2832912000.0
# Start of iteration 620
# Current loss value: 2048553000.0
# Start of iteration 621
# Current loss value: 2048472300.0
# Start of iteration 622
# Current loss value: 2048381600.0
# Start of iteration 623
# Current loss value: 2048309800.0
# Start of iteration 624
# Current loss value: 2048243300.0
# Start of iteration 625
# Current loss value: 2048173000.0
# Start of iteration 626
# Current loss value: 2048107800.0
# Start of iteration 627
# Current loss value: 2048041700.0
# Start of iteration 628
# Current loss value: 2047972400.0
# Start of iteration 629
# Current loss value: 2047914400.0
# Start of iteration 630
# Current loss value: 2047859800.0
# Start of iteration 631
# Current loss value: 2047806600.0
# Start of iteration 632
# Current loss value: 2047760000.0
# Start of iteration 633
# Current loss value: 2047718700.0
# Start of iteration 634
# Current loss value: 2047673000.0
# Start of iteration 635
# Current loss value: 2047620000.0
# Start of iteration 636
# Current loss value: 2047565300.0
# Start of iteration 637
# Current loss value: 2047513900.0
# Start of iteration 638
# Current loss value: 2047462900.0
# Start of iteration 639
# Current loss value: 2047415600.0
# Start of iteration 640
# Current loss value: 2047361800.0
# Start of iteration 641
# Current loss value: 2047312300.0
# Start of iteration 642
# Current loss value: 2047262000.0
# Start of iteration 643
# Current loss value: 2047222300.0
# Start of iteration 644
# Current loss value: 2047178200.0
# Start of iteration 645
# Current loss value: 2047137900.0
# Start of iteration 646
# Current loss value: 2047094300.0
# Start of iteration 647
# Current loss value: 2047059200.0
# Start of iteration 648
# Current loss value: 2047019800.0
# Start of iteration 649
# Current loss value: 2046985300.0
# Start of iteration 650
# Current loss value: 2046956500.0
# Start of iteration 651
# Current loss value: 2046930700.0
# Start of iteration 652
# Current loss value: 2046904800.0
# Start of iteration 653
# Current loss value: 2046879500.0
# Start of iteration 654
# Current loss value: 2046854500.0
# Start of iteration 655
# Current loss value: 2046830200.0
# Start of iteration 656
# Current loss value: 2046805500.0
# Start of iteration 657
# Current loss value: 2046779500.0
# Start of iteration 658
# Current loss value: 2046750200.0
# Start of iteration 659
# Current loss value: 2046710500.0
# Start of iteration 660
# Current loss value: 2046670600.0
# Start of iteration 661
# Current loss value: 2046630700.0
# Start of iteration 662
# Current loss value: 2046588400.0
# Start of iteration 663
# Current loss value: 2046537100.0
# Start of iteration 664
# Current loss value: 2046497300.0
# Start of iteration 665
# Current loss value: 2046457300.0
# Start of iteration 666
# Current loss value: 2046426100.0
# Start of iteration 667
# Current loss value: 2046391600.0
# Start of iteration 668
# Current loss value: 2046354800.0
# Start of iteration 669
# Current loss value: 2046310100.0
# Start of iteration 670
# Current loss value: 2046248100.0
# Start of iteration 671
# Current loss value: 2046197900.0
# Start of iteration 672
# Current loss value: 2046148400.0
# Start of iteration 673
# Current loss value: 2046086400.0
# Start of iteration 674
# Current loss value: 2046027400.0
# Start of iteration 675
# Current loss value: 2045983200.0
# Start of iteration 676
# Current loss value: 2045944700.0
# Start of iteration 677
# Current loss value: 2045912300.0
# Start of iteration 678
# Current loss value: 2045863200.0
# Start of iteration 679
# Current loss value: 2045817300.0
# Start of iteration 680
# Current loss value: 2045779000.0
# Start of iteration 681
# Start of iteration 741
# Current loss value: 2044368500.0
# Start of iteration 742
# Current loss value: 2044357800.0
# Start of iteration 743
# Current loss value: 2044346900.0
# Start of iteration 744
# Current loss value: 2044335000.0
# Start of iteration 745
# Current loss value: 2044319700.0
# Start of iteration 746
# Current loss value: 2044306200.0
# Start of iteration 747
# Current loss value: 2044291100.0
# Start of iteration 748
# Current loss value: 2044277000.0
# Start of iteration 749
# Current loss value: 2044260200.0
# Start of iteration 750
# Current loss value: 2044241400.0
# Start of iteration 751
# Current loss value: 2044223000.0
# Start of iteration 752
# Current loss value: 2044199400.0
# Start of iteration 753
# Current loss value: 2044168600.0
# Start of iteration 754
# Current loss value: 2044132000.0
# Start of iteration 755
# Current loss value: 2044104600.0
# Start of iteration 756
# Current loss value: 2044076300.0
# Start of iteration 757
# Current loss value: 2044044700.0
# Start of iteration 758
# Current loss value: 2044005900.0
# Start of iteration 759
# Current loss value: 2043964900.0
# Start of iteration 760
# Current loss value: 2043929200.0
# Start of iteration 761
# Current loss value: 2043898000.0
# Start of iteration 762
# Current loss value: 2043872300.0
# Start of iteration 763
# Current loss value: 2043850600.0
# Start of iteration 764
# Current loss value: 2043829900.0
# Start of iteration 765
# Current loss value: 2043809800.0
# Start of iteration 766
# Current loss value: 2043790800.0
# Start of iteration 767
# Current loss value: 2043771000.0
# Start of iteration 768
# Current loss value: 2043751700.0
# Start of iteration 769
# Current loss value: 2043730700.0
# Start of iteration 770
# Current loss value: 2043710700.0
# Start of iteration 771
# Current loss value: 2043692500.0
# Start of iteration 772
# Current loss value: 2043678200.0
# Start of iteration 773
# Current loss value: 2043666800.0
# Start of iteration 774
# Current loss value: 2043657100.0
# Start of iteration 775
# Current loss value: 2043648900.0
# Start of iteration 776
# Current loss value: 2043641100.0
# Start of iteration 777
# Current loss value: 2043634200.0
# Start of iteration 778
# Current loss value: 2043628000.0
# Start of iteration 779
# Current loss value: 2043622700.0
# Start of iteration 780
# Current loss value: 2043622100.0
# Start of iteration 781
# Current loss value: 2043622100.0
# Start of iteration 782
# Current loss value: 2043622100.0
# Start of iteration 783
# Current loss value: 2043622100.0
# Start of iteration 784
# Current loss value: 2043622100.0
# Start of iteration 785
# Current loss value: 2043622100.0
# Start of iteration 786
# Current loss value: 2043622100.0
# Start of iteration 787
# Current loss value: 2043621900.0
# Start of iteration 788
# Current loss value: 2043621900.0
# Start of iteration 789
# Current loss value: 2043621900.0
# Start of iteration 790
# Current loss value: 2043621900.0
# Start of iteration 791
# Current loss value: 2043621900.0
# Start of iteration 792
# Current loss value: 2043621900.0
# Start of iteration 793
# Current loss value: 2043621900.0
# Start of iteration 794
# Current loss value: 2043621900.0
# Start of iteration 795
# Current loss value: 2043621900.0
# Start of iteration 796
# Current loss value: 2043621900.0
# Start of iteration 797
# Current loss value: 2043621900.0
# Start of iteration 798
# Current loss value: 2043621900.0
# Start of iteration 799
# Current loss value: 2043621900.0
# Image saved as /content/drive/My Drive/Colab Notebooks/Neural Style Transfer/TeoTries/teo_toollateralus_at_iteration_799.png
# Iteration 799 completed in 1503s
